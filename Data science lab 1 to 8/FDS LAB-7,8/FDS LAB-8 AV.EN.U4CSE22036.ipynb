# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
d1 = pd.read_csv('uk-500.csv')
d1.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web
# 0  http://www.alandrosenburgcpapc.co.uk
# 1     http://www.capgeminiamerica.co.uk
# 2      http://www.elliottjohnwesq.co.uk
# 3          http://www.mcmahanbenl.co.uk
# 4        http://www.champagneroom.co.uk

# %% [markdown]
# **Population and Samples**
#
#  Sampling Techniques
#
# Simple Random Sampling
#
# ***df.sample(n=None, frac=None, replace=False, weights=None, random_state=None, axis=None)***
#
# n: The number of random rows to return (default is 1).
#
# frac: A fraction of rows to return. For example, frac=0.1 would return 10% of the DataFrame's rows.
#
# replace: Allows sampling with or without replacement. If replace=True, a row can be selected multiple times.
#
# weights: The relative weights of each row for sampling. If None, all rows have equal weight.
#
# random_state: A seed for the random number generator. Useful for reproducibility of results.
#
# axis: Axis to sample along. 0 or index to sample rows, and 1 or columns to sample columns.

# %%
d1.sample(n=3)
# Out:
#     first_name last_name          company_name           address  \
# 297   Clarinda    Pelayo           Tejas Loans     714 Moored St
# 318      Glory       Ona  Real Isle Properties  9830 Croxteth Rd
# 47       Luisa  Devereux         Cash 4 Checks  3 North View #35
#
#                                city          county    postal        phone1  \
# 297  Trelawnyd and Gwaenysgor Commu    Denbighshire  LL18 6DH  01902-887021
# 318           Pontefract North Ward  West Yorkshire   WF8 3YR  01469-868357
# 47   Burmantofts and Richmond Hill   West Yorkshire   LS9 7JH  01607-269930
#
#            phone2                 email                                  web
# 297  01824-104045  cpelayo@pelayo.co.uk          http://www.tejasloans.co.uk
# 318  01535-699216   glory_ona@gmail.com  http://www.realisleproperties.co.uk
# 47   01334-807355   ldevereux@gmail.com          http://www.cashchecks.co.uk

# %%
d1.sample(frac=0.1)
# Out:
#     first_name    last_name                    company_name  \
# 237    Rodolfo     Scavuzzo  Gulf Atlantic Equipment Co Inc
# 257   Rebbecca    Rufenacht         Ithaca Guitar Works Inc
# 400     Leeann        Flory  Fleetwood Area School District
# 123       Sean     Schurman       Cooper Electric Supply Co
# 475      Ivory      Lohrenz                 Auto Body Color
# 408     Remona        Heier          M A C Insurance Agency
# 311         In         Muns                    Nursefinders
# 381     Ashley        Tropp            Everythings A Dollar
# 397     Sabina         Prok       T J Ward & Associates Inc
# 154     Crista     Viengxay        Green Point Savings Bank
# 440    Lovetta        Study         Borton Petrini & Conron
# 398    Elenore      Gomoran        Bell Service Systems Inc
# 174        Val     Cellucci          Owensboro Brick & Tile
# 297   Clarinda       Pelayo                     Tejas Loans
# 119    Rodrigo       Hawkin            Godfroy, William Esq
# 178      Dacia    Swaisgood      Nelson & Paulson Chartered
# 161    Phillip         Aloi             Duffield, Michael C
# 498  Celestina        Keeny        Bfg Federal Credit Union
# 364      Billy        Selma                      Taylor Inn
# 150       Tran     Mandiola    N Rockland Educl Fed Crdt Un
# 493       Pura      Manciel                  Cia Inspection
# 10    Fernanda       Writer            K & R Associates Inc
# 340    Shannon    Kobayashi                           Hungs
# 425      Chana       Perera      Olden Camera & Lens Co Inc
# 256      Queen       Leader                Ottumwa Glass Co
# 198     Vashti        Sugai           Accurate Engraving Co
# 230        Flo     Bardsley             Hancock, John J Esq
# 52        Rory    Neufville               Brady, Brad J Esq
# 172       Dana  Paluszynski           Chile Pepper Magazine
# 153    Cheryll       Yurich      Blaineco Structural Movers
# 489   Krystina   Schlabaugh           Harris Oldsmobile Inc
# 489          http://www.harrisoldsmobileinc.co.uk
# 305      http://www.advantagetitleescrowinc.co.uk
# 44            http://www.generalappraisalco.co.uk
# 463         http://www.regisbrdproengrsland.co.uk
# 149                    http://www.computemp.co.uk
# 267              http://www.cleasingcompany.co.uk
# 45         http://www.sheratoninnoceanfront.co.uk
# 299                 http://www.dailyadvance.co.uk
# 419     http://www.smtothbaldridgevanbelkum.co.uk
# 283                  http://www.wkyamstereo.co.uk
# 164                http://www.desktopcenter.co.uk
# 88                  http://www.lovitchalanf.co.uk
# 224         http://www.aviationinsuranceinc.co.uk
# 416                  http://www.edminiatinc.co.uk
# 57        http://www.barajasbustamantearchl.co.uk
# 179     http://www.capitalthrpysptsmedcninc.co.uk
# 320      http://www.realestateappraisalsinc.co.uk
# 345    http://www.marinesafetyinternational.co.uk
# 53                 http://www.welderssupply.co.uk
# 409        http://www.audreymborlandstudios.co.uk

# %%
d1.sample(n=3, replace=True)
# Out:
#     first_name  last_name                    company_name           address  \
# 318      Glory        Ona            Real Isle Properties  9830 Croxteth Rd
# 236    Therese    Shiraki                     Wuhf Fox 31        18 Ouse St
# 179      Myong  Babineaux  Capital Thrpy & Spts Medcn Inc     2 Kirkdale Rd
#
#                               city           county    postal        phone1  \
# 318          Pontefract North Ward   West Yorkshire   WF8 3YR  01469-868357
# 236  Oakridge and Castlefield Ward  Buckinghamshire  HP11 2PJ  01611-691262
# 179        Canning Town North Ward   Greater London   E16 4NF  01897-419567
#
#            phone2                       email  \
# 318  01535-699216         glory_ona@gmail.com
# 236  01703-441371          tshiraki@gmail.com
# 179  01801-288675  mbabineaux@babineaux.co.uk
#
#                                            web
# 318        http://www.realisleproperties.co.uk
# 236                   http://www.wuhffox.co.uk
# 179  http://www.capitalthrpysptsmedcninc.co.uk

# %% [markdown]
# If you the above cell repeatedly you will get different results everytime.

# %%
d1.sample(n=3, random_state=1)
# Out:
#     first_name   last_name          company_name           address  \
# 304   Remedios  Arlinghaus  Miller, Martin M Esq  9 Duckenfield St
# 340    Shannon   Kobayashi                 Hungs  1111 Nesfield St
# 47       Luisa    Devereux         Cash 4 Checks  3 North View #35
#
#                                city                 county    postal  \
# 304                       Aldbrough  E Riding of Yorkshire  HU11 4QA
# 340      Tonge with the Haulgh Ward     Greater Manchester   BL2 2SU
# 47   Burmantofts and Richmond Hill          West Yorkshire   LS9 7JH
#
#            phone1        phone2                          email  \
# 304  01536-498792  01883-435283  remedios.arlinghaus@gmail.com
# 340  01620-435994  01436-122588              shannon@yahoo.com
# 47   01607-269930  01334-807355            ldevereux@gmail.com
#
#                                    web
# 304  http://www.millermartinmesq.co.uk
# 340             http://www.hungs.co.uk
# 47         http://www.cashchecks.co.uk

# %% [markdown]
# If you execute the above cell repeatedly, you will get the same results repeatedly.
# not only 1 , you can fix any seed value like 2,3 e.t.c.,
# but popular value is 42

# %%
d1.sample(frac=0.10, replace=True, random_state=5)
# Out:
#      first_name   last_name                    company_name  \
# 355     Margery       Rohrs   C G Mccullough Insurance Agcy
# 206     Ashanti        Donn                      Denticator
# 495       Avery        Veit      Plaza Gourmet Delicatessen
# 189        Zita      Speltz                Mmm Design Group
# 206                   http://www.denticator.co.uk
# 495     http://www.plazagourmetdelicatessen.co.uk
# 189               http://www.mmmdesigngroup.co.uk
# 486                http://www.tcesystemsinc.co.uk
# 118       http://www.sunderlandpublishingco.co.uk
# 400  http://www.fleetwoodareaschooldistrict.co.uk
# 73                http://www.goedouglaseesq.co.uk
# 8                  http://www.bizerbausainc.co.uk
# 228             http://www.bremerduncansesq.co.uk
# 231            http://www.transbaysteelcorp.co.uk
# 446              http://www.cohenandfrommpc.co.uk
# 411             http://www.hollettbyronpesq.co.uk
# 112             http://www.thornsjodaleoesq.co.uk
# 158              http://www.eaglenewspapers.co.uk
# 208            http://www.gallagherjohnjesq.co.uk
# 7            http://www.incommunicationsinc.co.uk
# 204          http://www.coastaltechnologies.co.uk
# 399  http://www.magicvalleyirrigationsupply.co.uk
# 113      http://www.manhattansupplycodeerpk.co.uk
# 437            http://www.brennerstevengesq.co.uk
# 487    http://www.rockspringspetroleumequip.co.uk
# 80            http://www.tremontmichaelaesq.co.uk
# 27           http://www.portalmetalproducts.co.uk
# 44            http://www.generalappraisalco.co.uk
# 205             http://www.goodfellowagency.co.uk
# 203      http://www.valleyprodnctrforvidaud.co.uk
# 65           http://www.lutzchristophertesq.co.uk
# 431                  http://www.kenneymfgco.co.uk
# 30              http://www.berickjosephgesq.co.uk
# 468      http://www.bestwstrnhostmtrhtlpalm.co.uk
# 86             http://www.mattparrottsonsco.co.uk
# 125         http://www.blantonmaryrattorney.co.uk
# 146                   http://www.mdwrailway.co.uk
# 254              http://www.heringglennzesq.co.uk
# 377             http://www.percivalmarkresq.co.uk
# 137                   http://www.haarallenf.co.uk
# 362               http://www.robertvanceltd.co.uk
# 41         http://www.ernesteheuercompanypc.co.uk
# 489          http://www.harrisoldsmobileinc.co.uk
# 446              http://www.cohenandfrommpc.co.uk
# 385            http://www.cappelloabarryesq.co.uk
# 210                   http://www.ruggallery.co.uk
# 103  http://www.agribusinessinsuranceagency.co.uk
# 144             http://www.youngdoorcompany.co.uk
# 462                      http://www.fhkcorp.co.uk
# 5            http://www.thompsonmichaelcesq.co.uk
# 314        http://www.mitchellsillimancoinc.co.uk
# 256               http://www.ottumwaglassco.co.uk
# 464                 http://www.malepowerltd.co.uk

# %%
d1.sample(n=5, replace=True, random_state=42)
# Out:
#     first_name  last_name                   company_name          address  \
# 102     Graham   Stanwick  Tiburon Pen Chmbr Commrce Inc  73 Hawkstone St
# 435     Dudley  Dibartolo         Mcknight, H Vincent Jr     91 Ludlow St
# 348      Jacob     Kippel             Acc Automation Inc    4 Monmouth Rd
# 270    Charlie      Isita           Sotorrio, Rene A Esq  39 Hooton Place
# 106    Shawana     Cantua     Best Western Riverview Inn     33 Vipond St
#
#                                city              county    postal  \
# 102  Renfrew South & Gallowhill War      Dunbartonshire   G52 4YG
# 435                  Woodhouse Ward      Greater London   N12 0EF
# 348           Llwyn-y-Pia Community  Rhondda Cynon Taff  CF40 2JJ
# 270  Neilston, Uplawmoor and Newton   East Renfrewshire   G78 3AB
# 106              Woodhall Farm Ward       Hertfordshire   HP2 7JP
#
#            phone1        phone2                       email  \
# 102  01860-191930  01409-786106         gstanwick@gmail.com
# 435  01997-409950  01722-935404  dudley_dibartolo@yahoo.com
# 348  01550-463222  01567-215689      jacob.kippel@yahoo.com
# 270  01295-844061  01796-315694         charlie@isita.co.uk
# 106  01413-348876  01659-621050           shawana@yahoo.com
#
#                                             web
# 102  http://www.tiburonpenchmbrcommrceinc.co.uk
# 435         http://www.mcknighthvincentjr.co.uk
# 348           http://www.accautomationinc.co.uk
# 270           http://www.sotorrioreneaesq.co.uk
# 106    http://www.bestwesternriverviewinn.co.uk

# %% [markdown]
# Stratified Sampling

# %%
d2 = pd.read_csv('StudentsPerformance.csv')
d2.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.histplot(d2['race/ethnicity'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='race/ethnicity', ylabel='Count'>

# %%
d2.groupby('race/ethnicity', group_keys=False).apply(lambda x:x.sample(min(len(x),3)))
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 892  female        group A             master's degree  free/reduced
# 46   female        group A          associate's degree      standard
# 576    male        group A                some college      standard
# 818  female        group B                 high school  free/reduced
# 333    male        group B          associate's degree      standard
# 776  female        group B                 high school      standard
# 27   female        group C           bachelor's degree      standard
# 357  female        group C                some college  free/reduced
# 672  female        group C                some college      standard
# 518  female        group D            some high school      standard
# 865    male        group D                some college      standard
# 617    male        group D           bachelor's degree      standard
# 802  female        group E          associate's degree      standard
# 886  female        group E          associate's degree      standard
# 79   female        group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 892                    none          50             67             73
# 46                completed          55             65             62
# 576               completed          61             51             52
# 818                    none          60             72             68
# 333                    none          90             78             81
# 776                    none          66             72             70
# 27                     none          67             69             75
# 357               completed          42             66             69
# 672                    none          69             78             76
# 518               completed          66             78             78
# 865               completed          82             82             88
# 617                    none          88             78             83
# 802                    none          87             94             95
# 886               completed          93            100             95
# 79                     none          62             68             68

# %% [markdown]
# For each unique "race/ethnicity" group, it randomly samples up to 3 rows.
# If a group has fewer than 3 rows, it returns all rows from that group.
# The result is a new DataFrame consisting of a random sample of up to 3 rows from each "race/ethnicity" group.

# %%
d2.groupby('gender', group_keys=False).apply(lambda x:x.sample(min(len(x),3)))
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 441  female        group D                 high school      standard
# 360  female        group B                 high school      standard
# 820  female        group A            some high school      standard
# 557    male        group C             master's degree  free/reduced
# 170    male        group A                 high school      standard
# 570    male        group B                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 441                    none          78             81             80
# 360                    none          58             62             59
# 820               completed          85             90             92
# 557                    none          61             67             66
# 170               completed          72             73             74
# 570               completed          71             75             70

# %% [markdown]
# Systematic sampling

# %%
step_size = 6
d2.iloc[::step_size]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 6    female        group B                some college      standard
# 12   female        group B                 high school      standard
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 972  female        group A                 high school  free/reduced
# 978    male        group D                 high school      standard
# 984  female        group C            some high school      standard
# 990    male        group E                 high school  free/reduced
# 996    male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 6                 completed          88             95             92
# 12                     none          65             81             73
# 18                completed          46             42             46
# 24                completed          74             71             80
# ..                      ...         ...            ...            ...
# 972               completed          53             50             60
# 978               completed          55             41             48
# 984                    none          74             75             82
# 990               completed          86             81             75
# 996                    none          62             55             55
#
# [167 rows x 8 columns]

# %% [markdown]
# Frequency Distribution
# Range

# %%
reading_range = np.amax(d2['reading score'])-np.amin(d2['reading score'])
reading_range
# Out:
# 83

# %% [markdown]
# Number of classes

# %%
num_of_classes=6

# %% [markdown]
# Class Interval

# %%
class_interval = reading_range/num_of_classes
class_interval
# Out:
# 13.833333333333334

# %% [markdown]
# Class Midpoint
#
# Relative Frequency

# %%
d2['reading score'].value_counts()
# Out:
# reading score
# 72    34
# 74    33
# 64    32
# 67    30
# 73    30
#       ..
# 28     1
# 26     1
# 17     1
# 32     1
# 40     1
# Name: count, Length: 72, dtype: int64

# %% [markdown]
# Cumulative Frequency

# %% [markdown]
# Cumulative Frequency

# %%
d2['reading score'].value_counts().cumsum()
# Out:
# reading score
# 72      34
# 74      67
# 64      99
# 67     129
# 73     159
#       ...
# 28     996
# 26     997
# 17     998
# 32     999
# 40    1000
# Name: count, Length: 72, dtype: int64

# %% [markdown]
# Measures of central tendency
#
# Mean

# %%
d2['math score'].mean()
# Out:
# 66.089

# %% [markdown]
# axis=0 (default): Compute the mean column-wise. Each column's values are averaged.
#
# skipna=True (default): Exclude NaN (missing) values when calculating the mean. If set to False, any NaN values will result in the mean being NaN for that column.
#
# numeric_only=None (default): If set to True, it only calculates the mean for numeric columns. If set to None (the default), it will try to infer whether to ignore non-numeric columns.

# %%
d2.mean(axis=0, skipna=True, numeric_only=True)
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %% [markdown]
# Median

# %%
d2['reading score'].median()
# Out:
# 70.0

# %% [markdown]
# MOde

# %%
d2['reading score'].mode()
# Out:
# 0    72
# Name: reading score, dtype: int64

# %% [markdown]
# Percentile

# %%
d2.quantile(.2, axis = 0,numeric_only=True)
# Out:
# math score       53.0
# reading score    57.0
# writing score    54.0
# Name: 0.2, dtype: float64

# %%
d2.quantile([.1, .3, .63, .95], axis = 0,numeric_only=True)
# Out:
#       math score  reading score  writing score
# 0.10       47.00          51.00           48.0
# 0.30       59.00          62.00           60.0
# 0.63       71.00          74.37           74.0
# 0.95       90.05          92.00           92.0

# %% [markdown]
# Quartile

# %%
d2.quantile([.25, .50, .75], axis = 0,numeric_only=True)
# Out:
#       math score  reading score  writing score
# 0.25        57.0           59.0          57.75
# 0.50        66.0           70.0          69.00
# 0.75        77.0           79.0          79.00

# %% [markdown]
# Measures of variance

# %%
d3 = pd.read_csv('nba.csv')
d3.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
d3.skew(axis=0, skipna=True, numeric_only=True)
# Out:
# Number    1.668386
# Age       0.626349
# Weight    0.113788
# Salary    1.576321
# dtype: float64

# %% [markdown]
# The data for Number and Salary is significantly right-skewed, indicating potential outliers or higher values stretching the distribution.
#
# The Age column is moderately skewed to the right.
#
# The Weight column is nearly symmetrical, meaning the data is balanced around the mean without a strong skew.

# %%
d3['Salary'].sort_values().hist().plot(use_index=False)
# Out:
# []

# %%
sns.boxplot(d3['Salary'])
# Out:
# <Axes: >

# %% [markdown]
# Kurtosis

# %%
d3.kurtosis(numeric_only=True)
# Out:
# Number    4.364464
# Age      -0.051119
# Weight   -0.552546
# Salary    1.839177
# dtype: float64

# %% [markdown]
# Number (4.36): Highly leptokurtic, indicating heavy tails and more extreme values or outliers.
#
# Age (-0.05): Nearly mesokurtic (close to 0), suggesting a near-normal distribution with few outliers.
#
# Weight (-0.55): Platykurtic, indicating light tails with fewer extreme values or outliers.
#
# Salary (1.84): Slightly leptokurtic, suggesting moderate tails with some outliers.
